# %% [markdown]
# # Imports

# %%
import pandas as pd
import json

# %% [markdown]
# # Experiment 3

# %% [markdown]
# ## Import data

# %%
# Experiment 4
data_path_exp4 = "../experiments/experiment4/data/data.csv"
# Experiment 5
data_path_exp5 = "../experiments/experiment5/data/data.csv"

# %%
# Read in data
data_exp4 = pd.read_csv(data_path_exp4)
data_exp5 = pd.read_csv(data_path_exp5)

# %%
data_exp4['experiment_version'] = 4

# %%
data_exp4['experiment_version'] = 5

# %%
data = pd.concat([data_exp4,data_exp5],ignore_index=True)

# %%
# Out:
#        trial_index                subject_id condition      rt response  \
# 0                0  6052437c8108f7a8de98b6c9         f     NaN      NaN
# 1                1  6052437c8108f7a8de98b6c9         f  1195.0
# 2                2  6052437c8108f7a8de98b6c9         f  4572.0        0
# 3                3  6052437c8108f7a8de98b6c9         f  2341.0
# 4                4  6052437c8108f7a8de98b6c9         f  1327.0
# ...            ...                       ...       ...     ...      ...
# 76313          524  616ed97200b22fa9725353b3         j   753.0
# 76314          525  616ed97200b22fa9725353b3         j     NaN      NaN
# 76315          526  616ed97200b22fa9725353b3         j     NaN      NaN
# 76316          527  616ed97200b22fa9725353b3         j  1007.0        j
# 76317          528  616ed97200b22fa9725353b3         j     NaN      NaN
#
#            task correct_response  attempts correct task_condition  \
# 0           NaN              NaN       NaN     NaN            NaN
# 1           NaN              NaN       NaN     NaN            NaN
# 2       consent              NaN       NaN     NaN            NaN
# 3           NaN              NaN       NaN     NaN            NaN
# 4           NaN              NaN       NaN     NaN            NaN
# ...         ...              ...       ...     ...            ...
# 76313    prompt              NaN       NaN     NaN            NaN
# 76314  fixation              NaN       NaN     NaN            NaN
# 76315       NaN              NaN       NaN     NaN            NaN
# 76316  response                j       NaN    True            yes
# 76317    prompt              NaN       NaN     NaN            NaN
#
#                       scene       scene_type  scene_index scene_col timed_out  \
# 0                       NaN              NaN          NaN       NaN       NaN
# 1                       NaN              NaN          NaN       NaN       NaN
# 2                       NaN              NaN          NaN       NaN       NaN
# 3                       NaN              NaN          NaN       NaN       NaN
# 4                       NaN              NaN          NaN       NaN       NaN
# ...                     ...              ...          ...       ...       ...
# 76313                   NaN              NaN          NaN       NaN       NaN
# 76314                   NaN              NaN          NaN       NaN       NaN
# 76315                   NaN              NaN          NaN       NaN       NaN
# 76316  stim_2_goalpos_1.mp4  stim_2_goalpos_          1.0       yes     False
# 76317                   NaN              NaN          NaN       NaN       NaN
#
#        experiment_version
# 0                     5.0
# 1                     5.0
# 2                     5.0
# 3                     5.0
# 4                     5.0
# ...                   ...
# 76313                 NaN
# 76314                 NaN
# 76315                 NaN
# 76316                 NaN
# 76317                 NaN
#
# [76318 rows x 16 columns]
