# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # Experiment 3

# %% [markdown]
# ## Import data

# %%
# Paths to data
data_path = "../experiments/experiment3/data/cleaned_data.json"

# %%
# Read in data
data = pd.read_json(data_path)

# %%
data
# Out:
#       trial_index                subject_id exp_condition    rt response_  \
# 0               0  61716480d6da1714ff60ed0d             j   884         f
# 1               1  61716480d6da1714ff60ed0d             j   726         f
# 2               2  61716480d6da1714ff60ed0d             j   885         f
# 3               3  61716480d6da1714ff60ed0d             j   981         f
# 4               4  61716480d6da1714ff60ed0d             j  1189         j
# ...           ...                       ...           ...   ...       ...
# 2251           43  5f145461435271023220d6ac             j  1551         f
# 2252           44  5f145461435271023220d6ac             j  1231         f
# 2253           45  5f145461435271023220d6ac             j   791         f
# 2254           46  5f145461435271023220d6ac             j   804         f
# 2255           47  5f145461435271023220d6ac             j   742         f
#
#           task correct_response  correct task_condition                scene  \
# ...
